# %% [markdown]
# ### CDS NYU
# ### DS-GA 3001 | Reinforcement Learning
# ### Lab 01
# ### January 30, 2025
#
#
# # Introduction to OpenAI Gym (Gymnasium)
#
# <br>
#
# ---

# %% [markdown]
# ## Section Leader
#
#
# Akshitha Kumbam – ak11071@nyu.edu
#
# Kushagra Khatwani – kk5395@nyu.edu

# %% [markdown]
# ## Goal of Today's Lab
#
# In this Lab, we will build "environments" in Gym to understand the key components involved when working with Gym. We will not implement any RL "agent" today so we can first focus on building RL interfaces in Gym, and interacting with Gym environments.
#
# In the rest of the course and all future labs, we will explore the many different ways for an RL agent to explore an environment, learn, and exploit its learning to make decisions. For today, let's just get comfortable setting up Gym simulation environments.
#
# ## Resources
#
# * Gym: https://www.gymlibrary.dev/ and its wiki https://github.com/openai/gym/wiki
# * The original paper from OpenAI when Gym was released in 2016: https://arxiv.org/pdf/1606.01540.pdf
# * In late 2022, Gym was moved to a new platform called Gymnasium, which is now **the only maintained version of Gym**: https://gymnasium.farama.org/
#
# <br>
#
# ---

# %% [markdown]
# # 1. Install libraries to set up RL environments in Gym

# %% [markdown]
# #### At the minimum, you need to create a virtual environment with Python and OpenAI Gym installed:
#
# `conda create --name py39 python=3.9`
#
# `conda activate py39`
#
# `pip install gym`
#
# `pip install gymnasium`
#
# To add the virtual env as kernel in Jupyter Notebook:
#
# `pip install ipykernel`
#
# `python -m ipykernel install --user --name=py39`
#
#
# #### Other libraries will soon be needed as the course progresses:
#
#
# * Install **extended Gym packages** (e.g., Atari games, etc): `pip install gym-all` or `conda install -c conda-forge gym-all`
#
# If you face issues installing gym-all, installing gym[atari,accept-rom-license] using the command: pip install gym[atari,accept-rom-license] should suffice
#
# Try this if you're getting the error: Env Breakout doesn't exist
#
# If you're using gymnasium as your library instead of gym, please run the command: pip install gymnasium[atari,accept-rom-license]
#
# * Install the **Arcade Learning Environment**: `pip install ale-py`
#
# * Install **box2d**:
# `pip install gym-box2d` or `conda install -c conda-forge gym-box2d`
#
#
# * Install **pygame**: `pip install pygame`
#
#
# * Install **tensorflow**:
# `pip install tensorflow` or `conda install -c conda-forge tensorflow`
#
#
# * Install **keras-rl2**:
# `pip install keras-rl2`

# %% [markdown]
# # 2. Build Reinforcement Learning environments in Gym
#
# In this section, we will build Reinforcement Learning environments in Gym to understand the key components involved when working with Gym. For today as RL "agent", we will use random action (random behavior), so we can focus just on the overall logic and Python commands when building RL interfaces in Gym and interacting with Gym environments.
#
# In the rest of the course and all future labs, we will explore the many different ways for an RL agent to explore an environment, learn, and exploit its learning to make decisions. For today, let's just get comfortable setting up Gym simulation environments.

# %% [markdown]
# ## 2.1) Build an Atari RL simulation environment: *Breakout video game*

# %% [markdown]
# Gym is a toolkit for developing and comparing reinforcement learning (RL) algorithms. It offers pre-built, baseline RL environments within which a developer can build and test RL algorithms.
#
# **At the most fundamental level, using the Gym library means 1) selecting an environment, and 2) interacting with it:**
#
# 1. **Gym offers many different environments to select, from classic control use cases (Pendulum, Cart-Pole, Blackjack, etc) to video games (Atari) and simulated robotics (MuJoCo)**. These use cases were selected by OpenAI in 2016 to represent problems that are tractable using existing (21st century) AI technologies, yet complex enough to showcase the need for human-like intelligence.
#
#
# 2. **Gym offers Python functions to interact with the created environment**. Most important ones are:
#     * `reset()`: Resets the state of the environment to the initial state (i.e., it restarts the game)
#     * `step(action)`:  Step forward by performing an action on the environment and returning the resulting state and reward after taking that action, a flag indicating if the game is over or not, and some metadata information
#
# The `reset` function returns one value, which is a starting state/observation.
#
# The `step` function returns four values, which we will call the ``next_state``, ``reward``,  ``done`` and ``info`` variables.
#
# -  ``next_state``: This is the observation that the agent will receive
#    after taking the action.
# -  ``reward``: This is the reward that the agent will receive after
#    taking the action.
# -  ``done``: This is a boolean variable that indicates whether or
#    not the environment has terminated.
# -  ``info``: This is a dictionary that might contain additional
#    information about the environment.
#
# In the Atari environments the ``info`` dictionary has a ``ale.lives`` key that tells us how many lives the
# agent has left. If the agent has 0 lives, then the episode is over.
#
#
# ### Here are the most basic Python commands to implement a Gym environments:
#
# A concise doc for the Atari Breakout video game available in Gym can be found here: https://gym.openai.com/envs/Breakout-v0/
#
# Note these basic commands are identical for all environments in Gym.
#
#
# **WARNING: Graphical rendering often crashes the Python kernel after completion => If this happens don't worry about it, just restart your kernel.** <br> (click on `Kernel`, then `Restart`)

# %%
import gymnasium as gym
import ale_py

gym.register_envs(ale_py) #This will register atari environments  in gymnasium

env = gym.make("Breakout-v0", render_mode="human") # Exact name/version of environments can be found in Gym's doc
observation = env.reset()
for _ in range(500):
    action = env.action_space.sample()  # this is where an actor (RL agent) would be inserted
    observation, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        observation = env.reset()
env.close()

# %% [markdown]
# **Warning:** The `render_mode="human"` argument renders the environment graphically in a separate window. It is optional, and not always recommended. It is not a good idea to use it when *training* an agent because rendering slows down training a lot. But when looking at an environment for the first time, or when training is complete, it can of course be useful to graphically vizualize how the agent behaves in the environment. But here is the warning: in Jupyter Notebook the Gym's graphical rendering works well but is likely to crash your kernel (or freeze it) once the simulation is complete. So as a habit, be ready to click on `Interrupt` and `Restart` in the Kernel tab of Jupyter Notebook after you run a simulation rendered graphically.

# %% [markdown]
# ### Play interactively with Atari video games in Gym
#
# Gym comes with a handy `utils` function called `play` for Atari games.
#
# Start the game by firing the ball with `space`, then move left and right with `a` and `d` on your keyboard.
#
# How many points can you score?

# %%
import gymnasium as gym
from gymnasium.utils.play import play  # Import the play module from gym.utils
import ale_py

gym.register_envs(ale_py) #This will register atari environments  in gymnasium

#Read the docs to decide the appropriate render mode for the environment. Edit the line below.
env = gym.make("Breakout-v0", render_mode = "rgb_array")    # Don't use render_mode='human' because this will open 2 windows when invoking the
                                 # method play below, and this redundancy can make your keyboard unresponsive

keys_to_action = {
    "a": 3,  # Move left
    "d": 2,  # Move right
    "s": 1,  # Fire the ball
}

play(env, zoom=2, keys_to_action=keys_to_action)                # Details of the 'play' function are here: https://gymnasium.farama.org/api/utils/

# %% [markdown]
# ### Useful command to interact with a Gym environment
#
# Let's look at some frequently used attributes and methods of a Gym environment, please checkout the concise doc here: https://gymnasium.farama.org/api/env/
#
# `render_mode` takes one argument which can take two possible values:
# * "human": Graphically render the state of the environment and display it on a laptop screen
# * "rgb_array": Returns an array of pixels containing the state (image) of the current environment
#
# `env.action_space` provides information on the action space, in particular `env.action_space.n` returns the number of possible actions
#
# `env.observation_space` provides information on the state space, in particular `env.observation_space.n` returns the number of states

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import ale_py

gym.register_envs(ale_py) #This will register atari environments  in gymnasium

env = gym.make("Breakout-v0", render_mode="rgb_array")

obs, info = env.reset()

array = env.render()  # Returns the image as a 2d numpy array

print("Color of the pixel at (60,50):", array[60][50])                  # Print one of the pixels - (row 60, column 50) corresponds to a red block

plt.imshow(array);                    # Vizualize the entire array of pixels in Matplotlib

# %% [markdown]
# In the case of the Atari video game Breakout, there are 4 possible actions: start the game (fire the ball), move left, move right, or stand still (do nothing)

# %%
print(f"There are {env.action_space.n} possible actions in Breakout")

# %% [markdown]
# We can invoke the method `sample` on `env.action_space` to select a random action amongst the possible actions. Note the "ale.lives" info reduces for each live lost.

# %%
import gymnasium as gym
import time      
import ale_py

gym.register_envs(ale_py) #This will register atari environments  in gymnasium
                                                   # Time package used to slown down vizual to human speed
env = gym.make("Breakout-v0", render_mode="human")
observation = env.reset()                                           # Initialize the environment to start state
for _ in range(200):
    random_action = env.action_space.sample()                       # Sample a random action
    observation, reward, terminated, truncated, info = env.step(random_action) # Step forward by performing action in current state
    print(f"Reward: {reward}, Done: {terminated}, Info: {info}")    # Print some of the metadata information
    time.sleep(0.01)                                                # Slow down the game so it's easier to follow visually
    if terminated or truncated:                                     # If game is over:
        observation = env.reset()                                   #    reset the game = initialize the env to start state
env.close()

# %% [markdown]
# ## 2.2) Build a Moon Lander RL simulation environment
#
# This environment is a simple rocket trajectory optimization problem.
#
# The goal is to land the rocket safely on the moon, using four possible actions: <br>
# `0`: Do nothing <br>
# `1`: Fire left orientation engine <br>
# `2`: Fire main engine <br>
# `3`: Fire right orientation engine
#
# Details can be found in the Gym/Gymnasium doc: https://gymnasium.farama.org/environments/box2d/lunar_lander/

# %%
import gymnasium as gym   # Gymnasium is the new, maintained version of Gym, most Gym env are directly compatible

env = gym.make("LunarLander-v3", render_mode="human")
observation, info = env.reset(seed=42)
for _ in range(1000):
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()
env.close()

# %% [markdown]
# ## 2.3) Build a Cart-Pole RL simulation environment
#
# This environment is a very popular, "classic" control use case: a pendulum ("pole") is attached by an un-actuated joint to a cart, placed upright on the cart, and the cart can move along a frictionless track.
#
# The pendulum is placed upright on the cart and The goal is to balance the pole (i.e., keep it upright within -12 to +12 degrees) by applying forces in the left and right direction on the cart, using two possible actions: <br>
# `0`: Push cart to the left <br>
# `1`: Push cart to the right
#
# **Challenges**: The episode terminates if the cart x-position gets outside the range [-2.4, 2.4] and/or the pole angle gets outside the range [-12°, 12°]. What makes this problem non-trivial is that the velocity which is reduced or increased by the applied force is not fixed and it depends on the angle the pole is pointing. The center of gravity of the pole varies the amount of energy needed to move the cart underneath it.
#
#
# Details can be found in the Gym/Gymnasium doc: https://gymnasium.farama.org/environments/classic_control/cart_pole/

# %%
import gymnasium as gym

env = gym.make('CartPole-v0', render_mode="human")
print('Cartpole has {} possible actions (either move left or right)'.format(env.action_space.n))

# Let's have a look at the starting state:
env.reset()
env.render()

# %% [markdown]
# # 3) Exercices
#
# ## 3.1) Exercice: Define an action-selection rule (not RL-based) for the Moon Lander
#
# **Run a simulation of the lunar lander for 2000 steps, firing the left engine whenever the x coordinate of the lander is < -0.1, firing the right engine whenever the x coordinate of the lander is > 0.1, and resetting its state whenever it lands or crashes**
#
# **Hint:** The state is an 8-dimensional vector: the coordinates of the lander in x & y, its linear velocities in x & y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not. Details can be found in the Gym/Gymnasium doc: https://gymnasium.farama.org/environments/box2d/lunar_lander/
#
# Again keep in mind today we do not build any "RL agent", none of the above or below material aims at 'learning' decisions, today we are just aim to better understand and interact with Gym environments

# %%
# Answer to question 3.1:
import gymnasium as gym

env = gym.make("LunarLander-v3", render_mode="human")
observation, info = env.reset(seed=42)
for _ in range(1000):
    if observation[0] > 0.1: 
        action = 1
    elif observation[0] < -0.1:
        action = 3
    else:
        action = 0
    
    print("x-coordinate: {}, action: {}".format(observation[0], action))
    # action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    
    if terminated or truncated:
        observation, info = env.reset()
env.close()

# %% [markdown]
#  ## 3.2) Exercice: Interactively control (non RL-based) the Cart-Pole

# %% [markdown]
# **Run simulations of the cartpole (as many as you like), and manually push the left and right arrows on your keyboard to try and keep the pole balanced by applying forces in the left and right direction on the cart. While you do so, print the cart velocity and the pole angle in degrees.**
#
# **Hint:** The state is an 4-dimensional vector: the cart position, the cart velocity, the pole angle, teh pole angular velocity. Details can be found in the Gym/Gymnasium doc: https://gymnasium.farama.org/environments/classic_control/cart_pole/
#
# Can you identify approximate thresholds of angle and velocity at which to start pushing either left or right?
#
# Again keep in mind today we do not build any "RL agent", none of the above or below material aims at 'learning' decisions, today we are just aim to better understand and interact with Gym environments.

# %% [markdown]
# #### There are two solutions for this. We may use the PlayPlot utility with a hacky function. Otherwise, we may use Gym with PyGame or Pyglet. Feel free to test both solutions!

# %%
import gymnasium as gym
from gymnasium.utils.play import PlayPlot, play

import math

# A callback function for the sake of printing the observations.
# Alternatively, we may plot the velocity and angle.
def show_state(obs_t, obs_tp, action, reward, terminated, truncated, info):
    vel, angle = obs_tp[1:3]
    angle = (angle * 180) / math.pi
    print(f"Velocity of cart: {vel}, angle of pole: {angle} degrees")
    return [vel, angle]

env = gym.make("CartPole-v1", render_mode="rgb_array")

# define the callback
plotter = PlayPlot(show_state, horizon_timesteps=1, plot_names=["Velocity", "Angle"])
# use `play` to render and map keys to their actions
# play(env, keys_to_action={"a": 0, "d": 1})
play(env, keys_to_action={"a": 0, "d": 1}, callback=plotter.callback)     #Can also change FPS here
# Out:
# Velocity of cart: -0.21348297595977783, angle of pole: 1.425478458404541 degrees
# Velocity of cart: -0.40895071625709534, angle of pole: 1.7566115856170654 degrees
# Velocity of cart: -0.6044882535934448, angle of pole: 2.4320058822631836 degrees
# Velocity of cart: -0.8001595139503479, angle of pole: 3.453673839569092 degrees
# Velocity of cart: -0.9960076212882996, angle of pole: 4.825669288635254 degrees
# Velocity of cart: -1.1920435428619385, angle of pole: 6.553986072540283 degrees
# Velocity of cart: -1.3882334232330322, angle of pole: 8.646411895751953 degrees
# Velocity of cart: -1.5844831466674805, angle of pole: 11.112310409545898 degrees
# Velocity of cart: -1.7806211709976196, angle of pole: 13.962353706359863 degrees
# Velocity of cart: -0.23914296925067902, angle of pole: -2.533694267272949 degrees
# Velocity of cart: -0.433606892824173, angle of pole: -2.2239928245544434 degrees
# Velocity of cart: -0.628162682056427, angle of pole: -1.595252275466919 degrees
# Velocity of cart: -0.8228931427001953, angle of pole: -0.6454209089279175 degrees
# Velocity of cart: -1.0178654193878174, angle of pole: 0.6296189427375793 degrees
# Velocity of cart: -1.2131221294403076, angle of pole: 2.2359750270843506 degrees
# Velocity of cart: -1.4086716175079346, angle of pole: 4.181634902954102 degrees
# Velocity of cart: -1.6044751405715942, angle of pole: 6.476307392120361 degrees
# Velocity of cart: -1.800431251525879, angle of pole: 9.131211280822754 degrees
# Velocity of cart: -1.9963585138320923, angle of pole: 12.158790588378906 degrees
# Velocity of cart: -0.16494767367839813, angle of pole: 2.020134925842285 degrees
# Velocity of cart: -0.3605528771877289, angle of pole: 2.420214891433716 degrees
# Velocity of cart: -0.5562368035316467, angle of pole: 3.168182134628296 degrees
# Velocity of cart: -0.752056896686554, angle of pole: 4.266432285308838 degrees
# Velocity of cart: -0.9480467438697815, angle of pole: 5.719377040863037 degrees
# Velocity of cart: -1.1442046165466309, angle of pole: 7.533334255218506 degrees
# Velocity of cart: -1.3404794931411743, angle of pole: 9.71635627746582 degrees
# Velocity of cart: -1.5367553234100342, angle of pole: 12.278007507324219 degrees
# Velocity of cart: -0.21058067679405212, angle of pole: 2.7803351879119873 degrees
# Velocity of cart: -0.40635889768600464, angle of pole: 3.1474978923797607 degrees
# Velocity of cart: -0.6022027730941772, angle of pole: 3.867124557495117 degrees
# Velocity of cart: -0.7981666922569275, angle of pole: 4.941372394561768 degrees
# Velocity of cart: -0.994281530380249, angle of pole: 6.374411582946777 degrees
# Velocity of cart: -1.190542221069336, angle of pole: 8.172313690185547 degrees
# Velocity of cart: -1.3868942260742188, angle of pole: 10.34288215637207 degrees
# Velocity of cart: -1.5832170248031616, angle of pole: 12.895417213439941 degrees
# Velocity of cart: -0.16602499783039093, angle of pole: 0.35934728384017944 degrees
# Velocity of cart: -0.3612358272075653, angle of pole: 0.6923398375511169 degrees
# Velocity of cart: -0.556524932384491, angle of pole: 1.3629813194274902 degrees
# Velocity of cart: -0.7519617676734924, angle of pole: 2.3733465671539307 degrees
# Velocity of cart: -0.9475961327552795, angle of pole: 3.7275617122650146 degrees
# Velocity of cart: -1.1434476375579834, angle of pole: 5.4317097663879395 degrees
# Velocity of cart: -1.3394935131072998, angle of pole: 7.493692398071289 degrees
# Velocity of cart: -1.535653829574585, angle of pole: 9.923030853271484 degrees
# Velocity of cart: -1.731774926185608, angle of pole: 12.73060131072998 degrees
# Velocity of cart: -0.18666993081569672, angle of pole: 2.4976353645324707 degrees
# Velocity of cart: -0.38238558173179626, angle of pole: 2.8253259658813477 degrees
# Velocity of cart: -0.5781619548797607, angle of pole: 3.503788709640503 degrees
# Velocity of cart: -0.7740569114685059, angle of pole: 4.534963130950928 degrees
# Velocity of cart: -0.9701064229011536, angle of pole: 5.922816753387451 degrees
# Velocity of cart: -1.166312575340271, angle of pole: 7.6732378005981445 degrees
# Velocity of cart: -1.362630009651184, angle of pole: 9.793874740600586 degrees
# Velocity of cart: -1.558950424194336, angle of pole: 12.293919563293457 degrees
# Velocity of cart: -0.24414189159870148, angle of pole: 2.205037832260132 degrees
# Velocity of cart: -0.4397909343242645, angle of pole: 2.5347015857696533 degrees
# Velocity of cart: -0.635503351688385, angle of pole: 3.2133750915527344 degrees
# Velocity of cart: -0.8313387632369995, angle of pole: 4.243022918701172 degrees
# Velocity of cart: -1.0273350477218628, angle of pole: 5.627642631530762 degrees
# Velocity of cart: -1.2234965562820435, angle of pole: 7.373157978057861 degrees
# Velocity of cart: -1.4197810888290405, angle of pole: 9.487262725830078 degrees
# Velocity of cart: -1.6160838603973389, angle of pole: 11.97920036315918 degrees
# Velocity of cart: -1.8122200965881348, angle of pole: 14.859472274780273 degrees
# Velocity of cart: -0.22039443254470825, angle of pole: 0.9470906257629395 degrees
# Velocity of cart: -0.4157477617263794, angle of pole: 1.3217219114303589 degrees
# Velocity of cart: -0.6111840605735779, angle of pole: 2.037663459777832 degrees
# Velocity of cart: -0.8067678809165955, angle of pole: 3.097217082977295 degrees
# Velocity of cart: -1.00254225730896, angle of pole: 4.504720687866211 degrees
# Velocity of cart: -1.1985175609588623, angle of pole: 6.266447067260742 degrees
# Velocity of cart: -1.3946586847305298, angle of pole: 8.390450477600098 degrees
# Velocity of cart: -1.5908697843551636, angle of pole: 10.886353492736816 degrees
# Velocity of cart: -1.786976933479309, angle of pole: 13.765069007873535 degrees
# Velocity of cart: -0.24000704288482666, angle of pole: 0.36458680033683777 degrees
# Velocity of cart: -0.43521907925605774, angle of pole: 0.7142972350120544 degrees
# Velocity of cart: -0.6305131912231445, angle of pole: 1.4016894102096558 degrees
# Velocity of cart: -0.8259581327438354, angle of pole: 2.428941249847412 degrees
# Velocity of cart: -1.0216023921966553, angle of pole: 3.800278663635254 degrees
# Velocity of cart: -1.2174638509750366, angle of pole: 5.521880149841309 degrees
# Velocity of cart: -1.4135173559188843, angle of pole: 7.601730823516846 degrees
# Velocity of cart: -1.6096798181533813, angle of pole: 10.04942798614502 degrees
# Velocity of cart: -1.805793285369873, angle of pole: 12.875906944274902 degrees
# Velocity of cart: -0.22756259143352509, angle of pole: 2.2313954830169678 degrees
# Velocity of cart: -0.42321696877479553, angle of pole: 2.5962839126586914 degrees
# Velocity of cart: -0.6189413666725159, angle of pole: 3.3103394508361816 degrees
# Velocity of cart: -0.814793586730957, angle of pole: 4.375736236572266 degrees
# Velocity of cart: -1.0108085870742798, angle of pole: 5.7966694831848145 degrees
# Velocity of cart: -1.2069867849349976, angle of pole: 7.579251289367676 degrees
# Velocity of cart: -1.4032800197601318, angle of pole: 9.731340408325195 degrees
# Velocity of cart: -1.5995763540267944, angle of pole: 12.262320518493652 degrees
# Velocity of cart: -0.16616907715797424, angle of pole: 0.24547916650772095 degrees
# Velocity of cart: -0.36135175824165344, angle of pole: 0.6185342669487 degrees
# Velocity of cart: -0.5566228032112122, angle of pole: 1.328524112701416 degrees
# Velocity of cart: -0.752050518989563, angle of pole: 2.377777338027954 degrees
# Velocity of cart: -0.9476825594902039, angle of pole: 3.7706668376922607 degrees
# Velocity of cart: -1.1435351371765137, angle of pole: 5.513510704040527 degrees
# Velocity of cart: -1.3395812511444092, angle of pole: 7.614427089691162 degrees
# Velocity of cart: -1.53573477268219, angle of pole: 10.08313274383545 degrees
# Velocity of cart: -1.7318341732025146, angle of pole: 12.930669784545898 degrees
# Velocity of cart: -0.2108127921819687, angle of pole: -1.698209285736084 degrees
# Velocity of cart: -0.40549924969673157, angle of pole: -1.4099496603012085 degrees
# Velocity of cart: -0.6002666354179382, angle of pole: -0.797179639339447 degrees
# Velocity of cart: -0.795195460319519, angle of pole: 0.14197978377342224 degrees
# Velocity of cart: -0.9903498888015747, angle of pole: 1.4114773273468018 degrees
# Velocity of cart: -1.1857690811157227, angle of pole: 3.0172548294067383 degrees
# Velocity of cart: -1.3814566135406494, angle of pole: 4.967129707336426 degrees
# Velocity of cart: -1.577366828918457, angle of pole: 7.270633697509766 degrees
# Velocity of cart: -1.7733900547027588, angle of pole: 9.938787460327148 degrees
# Velocity of cart: -1.9693340063095093, angle of pole: 12.983807563781738 degrees
# Velocity of cart: -0.23992878198623657, angle of pole: -0.7908546328544617 degrees
# Velocity of cart: -0.43485110998153687, angle of pole: -0.47359007596969604 degrees
# Velocity of cart: -0.6298561692237854, angle of pole: 0.1740393042564392 degrees
# Velocity of cart: -0.825019359588623, angle of pole: 1.1540615558624268 degrees
# Velocity of cart: -1.0203983783721924, angle of pole: 2.4705662727355957 degrees
# Velocity of cart: -1.2160232067108154, angle of pole: 4.12962007522583 degrees
# Velocity of cart: -1.4118849039077759, angle of pole: 6.139138221740723 degrees
# Velocity of cart: -1.6079216003417969, angle of pole: 8.50870418548584 degrees
# Velocity of cart: -1.804002285003662, angle of pole: 11.249329566955566 degrees
# Velocity of cart: -1.999908447265625, angle of pole: 14.37313175201416 degrees
# Velocity of cart: -0.1692657470703125, angle of pole: -0.6483442187309265 degrees
# Velocity of cart: -0.36422446370124817, angle of pole: -0.3307073414325714 degrees
# Velocity of cart: -0.5592649579048157, angle of pole: 0.3182051181793213 degrees
# Velocity of cart: -0.7544621229171753, angle of pole: 1.300417423248291 degrees
# Velocity of cart: -0.9498727321624756, angle of pole: 2.6200149059295654 degrees
# Velocity of cart: -1.1455256938934326, angle of pole: 4.28305721282959 degrees
# Velocity of cart: -1.3414106369018555, angle of pole: 6.297451972961426 degrees
# Velocity of cart: -1.5374637842178345, angle of pole: 8.672768592834473 degrees
# Velocity of cart: -1.7335518598556519, angle of pole: 11.41999626159668 degrees
# Velocity of cart: -1.929452896118164, angle of pole: 14.551222801208496 degrees
# Velocity of cart: -0.17924682796001434, angle of pole: -2.490142345428467 degrees
# Velocity of cart: -0.3737238347530365, angle of pole: -2.118870258331299 degrees
# Velocity of cart: -0.5683095455169678, angle of pole: -1.428269624710083 degrees
# Velocity of cart: -0.7630842924118042, angle of pole: -0.4158858358860016 degrees
# Velocity of cart: -0.958111047744751, angle of pole: 0.9227896928787231 degrees
# Velocity of cart: -1.1534267663955688, angle of pole: 2.5942375659942627 degrees
# Velocity of cart: -1.349031686782837, angle of pole: 4.606790542602539 degrees
# Velocity of cart: -1.544875979423523, angle of pole: 6.970467567443848 degrees
# Velocity of cart: -1.7408441305160522, angle of pole: 9.696747779846191 degrees
# Velocity of cart: -1.9367367029190063, angle of pole: 12.79826831817627 degrees
# Velocity of cart: -0.1661282181739807, angle of pole: -0.8937380909919739 degrees
# Velocity of cart: -0.36102399230003357, angle of pole: -0.6072548627853394 degrees
# Velocity of cart: -0.5559953451156616, angle of pole: 0.008933772332966328 degrees
# Velocity of cart: -0.7511194348335266, angle of pole: 0.9566640257835388 degrees
# Velocity of cart: -0.9464563727378845, angle of pole: 2.239840507507324 degrees
# Velocity of cart: -1.1420398950576782, angle of pole: 3.8643546104431152 degrees
# Velocity of cart: -1.3378660678863525, angle of pole: 5.837961673736572 degrees
# Velocity of cart: -1.5338797569274902, angle of pole: 8.170109748840332 degrees
# Velocity of cart: -1.7299587726593018, angle of pole: 10.87170124053955 degrees
# Velocity of cart: -1.925895094871521, angle of pole: 13.954782485961914 degrees
# Velocity of cart: -0.18523672223091125, angle of pole: 0.47955015301704407 degrees
# Velocity of cart: -0.38047704100608826, angle of pole: 0.8061559200286865 degrees
# Velocity of cart: -0.5757933259010315, angle of pole: 1.4711629152297974 degrees
# Velocity of cart: -0.7712545990943909, angle of pole: 2.4766006469726562 degrees
# Velocity of cart: -0.9669104814529419, angle of pole: 3.8265504837036133 degrees
# Velocity of cart: -1.1627801656723022, angle of pole: 5.5270514488220215 degrees
# Velocity of cart: -1.3588405847549438, angle of pole: 7.58596134185791 degrees
# Velocity of cart: -1.5550113916397095, angle of pole: 10.012754440307617 degrees
# Velocity of cart: -1.7511383295059204, angle of pole: 12.818265914916992 degrees
# Velocity of cart: -0.15027450025081635, angle of pole: 2.4454352855682373 degrees
# Velocity of cart: -0.34597885608673096, angle of pole: 2.747056484222412 degrees
# Velocity of cart: -0.5417393445968628, angle of pole: 3.399136781692505 degrees
# Velocity of cart: -0.7376152873039246, angle of pole: 4.4034647941589355 degrees
# Velocity of cart: -0.9336450099945068, angle of pole: 5.763861179351807 degrees
# Velocity of cart: -1.1298338174819946, angle of pole: 7.486080169677734 degrees
# Velocity of cart: -1.326141119003296, angle of pole: 9.577651977539062 degrees
# Velocity of cart: -1.5224640369415283, angle of pole: 12.047669410705566 degrees
# Velocity of cart: -0.19050104916095734, angle of pole: 1.7490228414535522 degrees
# Velocity of cart: -0.3860436677932739, angle of pole: 2.143345832824707 degrees
# Velocity of cart: -0.5816663503646851, angle of pole: 2.8839073181152344 degrees
# Velocity of cart: -0.7774283289909363, angle of pole: 3.9730844497680664 degrees
# Velocity of cart: -0.9733656644821167, angle of pole: 5.415276050567627 degrees
# Velocity of cart: -1.1694797277450562, angle of pole: 7.216792106628418 degrees
# Velocity of cart: -1.3657233715057373, angle of pole: 9.38569450378418 degrees
# Velocity of cart: -1.5619854927062988, angle of pole: 11.931564331054688 degrees
# Velocity of cart: -1.7580732107162476, angle of pole: 14.86520767211914 degrees
# Velocity of cart: -0.19044233858585358, angle of pole: 0.6449721455574036 degrees
# Velocity of cart: -0.38572317361831665, angle of pole: 0.9384636878967285 degrees
# Velocity of cart: -0.5810713171958923, angle of pole: 1.5713894367218018 degrees
# Velocity of cart: -0.7765562534332275, angle of pole: 2.5455665588378906 degrees
# Velocity of cart: -0.9722288846969604, angle of pole: 3.864870071411133 degrees
# Velocity of cart: -1.1681104898452759, angle of pole: 5.5351409912109375 degrees
# Velocity of cart: -1.3641808032989502, angle of pole: 7.564050197601318 degrees
# Velocity of cart: -1.560363531112671, angle of pole: 9.96090316772461 degrees
# Velocity of cart: -1.7565094232559204, angle of pole: 12.736384391784668 degrees
# Velocity of cart: -0.18410520255565643, angle of pole: -1.6200987100601196 degrees
# Velocity of cart: -0.378812313079834, angle of pole: -1.3239686489105225 degrees
# Velocity of cart: -0.5736019611358643, angle of pole: -0.7028204798698425 degrees
# Velocity of cart: -0.7685540914535522, angle of pole: 0.2452729344367981 degrees
# Velocity of cart: -0.9637319445610046, angle of pole: 1.5243066549301147 degrees
# Velocity of cart: -1.1591734886169434, angle of pole: 3.1402652263641357 degrees
# Velocity of cart: -1.354880452156067, angle of pole: 5.101006507873535 degrees
# Velocity of cart: -1.5508050918579102, angle of pole: 7.416093349456787 degrees
# Velocity of cart: -1.7468347549438477, angle of pole: 10.09657096862793 degrees
# Velocity of cart: -1.9427732229232788, angle of pole: 13.1546630859375 degrees
# Velocity of cart: -0.18296535313129425, angle of pole: 2.7087161540985107 degrees
# Velocity of cart: -0.37872734665870667, angle of pole: 3.0854032039642334 degrees
# Velocity of cart: -0.574557363986969, angle of pole: 3.8141257762908936 degrees
# Velocity of cart: -0.7705097794532776, angle of pole: 4.897100925445557 degrees
# Velocity of cart: -0.9666152000427246, angle of pole: 6.338557243347168 degrees
# Velocity of cart: -1.1628681421279907, angle of pole: 8.144624710083008 degrees
# Velocity of cart: -1.3592134714126587, angle of pole: 10.32315731048584 degrees
# Velocity of cart: -1.5555298328399658, angle of pole: 12.883509635925293 degrees
# Velocity of cart: -0.21129187941551208, angle of pole: 1.379947304725647 degrees
# Velocity of cart: -0.4067484736442566, angle of pole: 1.7414216995239258 degrees
# Velocity of cart: -0.6022815704345703, angle of pole: 2.4468770027160645 degrees
# Velocity of cart: -0.7979540824890137, angle of pole: 3.498511791229248 degrees
# Velocity of cart: -0.9938070774078369, angle of pole: 4.900559425354004 degrees
# Velocity of cart: -1.1898486614227295, angle of pole: 6.65918493270874 degrees
# Velocity of cart: -1.3860411643981934, angle of pole: 8.782329559326172 degrees
# Velocity of cart: -1.582284927368164, angle of pole: 11.279497146606445 degrees
# Velocity of cart: -1.7784018516540527, angle of pole: 14.16146469116211 degrees
# Velocity of cart: -0.16413237154483795, angle of pole: 1.1121248006820679 degrees
# Velocity of cart: -0.359525591135025, angle of pole: 1.4491406679153442 degrees
# Velocity of cart: -0.5549923181533813, angle of pole: 2.128488540649414 degrees
# Velocity of cart: -0.7505978941917419, angle of pole: 3.152231216430664 degrees
# Velocity of cart: -0.946386992931366, angle of pole: 4.524476051330566 degrees
# Velocity of cart: -1.142372727394104, angle of pole: 6.2512736320495605 degrees
# Velocity of cart: -1.3385237455368042, angle of pole: 8.340472221374512 degrees
# Velocity of cart: -1.534749150276184, angle of pole: 10.80151081085205 degrees
# Velocity of cart: -1.7308812141418457, angle of pole: 13.645136833190918 degrees
# Velocity of cart: -0.147785484790802, angle of pole: -0.5470470786094666 degrees
# Velocity of cart: -0.34277018904685974, angle of pole: -0.17531388998031616 degrees
# Velocity of cart: -0.5378492474555969, angle of pole: 0.5283414721488953 degrees
# Velocity of cart: -0.7330948710441589, angle of pole: 1.5662806034088135 degrees
# Velocity of cart: -0.9285594820976257, angle of pole: 2.9429144859313965 degrees
# Velocity of cart: -1.1242659091949463, angle of pole: 4.664610385894775 degrees
# Velocity of cart: -1.3201954364776611, angle of pole: 6.739553928375244 degrees
# Velocity of cart: -1.5162729024887085, angle of pole: 9.177556991577148 degrees
# Velocity of cart: -1.712350845336914, angle of pole: 11.989801406860352 degrees
# Velocity of cart: -1.9081894159317017, angle of pole: 15.188499450683594 degrees
# Velocity of cart: -0.14699144661426544, angle of pole: -1.9615594148635864 degrees
# Velocity of cart: -0.3416089713573456, angle of pole: -1.6268702745437622 degrees
# Velocity of cart: -0.5363215208053589, angle of pole: -0.969386100769043 degrees
# Velocity of cart: -0.7312089800834656, angle of pole: 0.01308471243828535 degrees
# Velocity of cart: -0.9263339042663574, angle of pole: 1.3247946500778198 degrees
# Velocity of cart: -1.1217330694198608, angle of pole: 2.9719767570495605 degrees
# Velocity of cart: -1.317406415939331, angle of pole: 4.962724208831787 degrees
# Velocity of cart: -1.5133039951324463, angle of pole: 7.306825160980225 degrees
# Velocity of cart: -1.7093098163604736, angle of pole: 10.015530586242676 degrees
# Velocity of cart: -1.9052239656448364, angle of pole: 13.10125732421875 degrees
# Velocity of cart: -0.148856982588768, angle of pole: -1.7264065742492676 degrees
# Velocity of cart: -0.3435359001159668, angle of pole: -1.4442294836044312 degrees
# Velocity of cart: -0.5382943749427795, angle of pole: -0.8377254605293274 degrees
# Velocity of cart: -0.7332130670547485, angle of pole: 0.09494607895612717 degrees
# Velocity of cart: -0.9283567667007446, angle of pole: 1.357696771621704 degrees
# Velocity of cart: -1.1237653493881226, angle of pole: 2.956432342529297 degrees
# Velocity of cart: -1.3194433450698853, angle of pole: 4.898939609527588 degrees
# Velocity of cart: -1.515346646308899, angle of pole: 7.19472074508667 degrees
# Velocity of cart: -1.7113672494888306, angle of pole: 9.85477352142334 degrees
# Velocity of cart: -1.9073150157928467, angle of pole: 12.891303062438965 degrees
# Velocity of cart: -0.17434918880462646, angle of pole: -2.0128564834594727 degrees
# Velocity of cart: -0.3689531087875366, angle of pole: -1.6760430335998535 degrees
# Velocity of cart: -0.5636530518531799, angle of pole: -1.0167697668075562 degrees
# Velocity of cart: -0.7585288286209106, angle of pole: -0.03282879665493965 degrees
# Velocity of cart: -0.953643262386322, angle of pole: 1.28004789352417 degrees
# Velocity of cart: -1.1490333080291748, angle of pole: 2.9281086921691895 degrees
# Velocity of cart: -1.3446990251541138, angle of pole: 4.919461727142334 degrees
# Velocity of cart: -1.540590763092041, angle of pole: 7.26391077041626 degrees
# Velocity of cart: -1.7365928888320923, angle of pole: 9.972723007202148 degrees
# Velocity of cart: -1.9325059652328491, angle of pole: 13.058333396911621 degrees
# Velocity of cart: -0.20049645006656647, angle of pole: 2.322493076324463 degrees
# Velocity of cart: -0.3961710035800934, angle of pole: 2.7125437259674072 degrees
# Velocity of cart: -0.5919196009635925, angle of pole: 3.452310562133789 degrees
# Velocity of cart: -0.787798285484314, angle of pole: 4.544111251831055 degrees
# Velocity of cart: -0.9838393926620483, angle of pole: 5.992278575897217 degrees
# Velocity of cart: -1.1800395250320435, angle of pole: 7.8030476570129395 degrees
# Velocity of cart: -1.3763458728790283, angle of pole: 9.984389305114746 degrees
# Velocity of cart: -1.5726398229599, angle of pole: 12.545769691467285 degrees
# Velocity of cart: -0.15587714314460754, angle of pole: -1.7104872465133667 degrees
# Velocity of cart: -0.350561261177063, angle of pole: -1.3576807975769043 degrees
# Velocity of cart: -0.5453435778617859, angle of pole: -0.6804423928260803 degrees
# Velocity of cart: -0.7403021454811096, angle of pole: 0.3235258162021637 degrees
# Velocity of cart: -0.9354971051216125, angle of pole: 1.658578634262085 degrees
# Velocity of cart: -1.1309618949890137, angle of pole: 3.3310437202453613 degrees
# Velocity of cart: -1.3266915082931519, angle of pole: 5.3490986824035645 degrees
# Velocity of cart: -1.5226298570632935, angle of pole: 7.722594261169434 degrees
# Velocity of cart: -1.7186528444290161, angle of pole: 10.462824821472168 degrees
# Velocity of cart: -1.9145503044128418, angle of pole: 13.582207679748535 degrees
# Velocity of cart: -0.21557411551475525, angle of pole: -1.7818354368209839 degrees
# Velocity of cart: -0.4102388918399811, angle of pole: -1.4656049013137817 degrees
# Velocity of cart: -0.6049926280975342, angle of pole: -0.8254075646400452 degrees
# Velocity of cart: -0.7999150156974792, angle of pole: 0.14082053303718567 degrees
# Velocity of cart: -0.9950690865516663, angle of pole: 1.4372074604034424 degrees
# Velocity of cart: -1.1904919147491455, angle of pole: 3.06986665725708 degrees
# Velocity of cart: -1.3861842155456543, angle of pole: 5.046777248382568 degrees
# Velocity of cart: -1.5820969343185425, angle of pole: 7.377617359161377 degrees
# Velocity of cart: -1.7781152725219727, angle of pole: 10.07353687286377 degrees
# Velocity of cart: -1.9740409851074219, angle of pole: 13.14686107635498 degrees
# Velocity of cart: -0.22630299627780914, angle of pole: 1.2060526609420776 degrees
# Velocity of cart: -0.42171868681907654, angle of pole: 1.5379235744476318 degrees
# Velocity of cart: -0.6172060370445251, angle of pole: 2.2127060890197754 degrees
# Velocity of cart: -0.8128300905227661, angle of pole: 3.2324275970458984 degrees
# Velocity of cart: -1.008635401725769, angle of pole: 4.601158618927002 degrees
# Velocity of cart: -1.204634666442871, angle of pole: 6.324915409088135 degrees
# Velocity of cart: -1.4007964134216309, angle of pole: 8.411510467529297 degrees
# Velocity of cart: -1.5970293283462524, angle of pole: 10.870345115661621 degrees
# Velocity of cart: -1.7931654453277588, angle of pole: 13.71213150024414 degrees
# Velocity of cart: -0.20821131765842438, angle of pole: 0.23602394759655 degrees
# Velocity of cart: -0.4033917188644409, angle of pole: 0.5908395051956177 degrees
# Velocity of cart: -0.5986563563346863, angle of pole: 1.282530426979065 degrees
# Velocity of cart: -0.7940744161605835, angle of pole: 2.3133130073547363 degrees
# Velocity of cart: -0.9896948337554932, angle of pole: 3.687450647354126 degrees
# Velocity of cart: -1.1855359077453613, angle of pole: 5.411159992218018 degrees
# Velocity of cart: -1.38157320022583, angle of pole: 7.492464542388916 degrees
# Velocity of cart: -1.5777244567871094, angle of pole: 9.941001892089844 degrees
# Velocity of cart: -1.7738325595855713, angle of pole: 12.767749786376953 degrees
# Velocity of cart: -0.21284115314483643, angle of pole: 2.798607110977173 degrees
# Velocity of cart: -0.4086238145828247, angle of pole: 3.151587724685669 degrees
# Velocity of cart: -0.6044694185256958, angle of pole: 3.8571419715881348 degrees
# Velocity of cart: -0.8004328608512878, angle of pole: 4.917342185974121 degrees
# Velocity of cart: -0.9965459108352661, angle of pole: 6.336279392242432 degrees
# Velocity of cart: -1.1928051710128784, angle of pole: 8.11994743347168 degrees
# Velocity of cart: -1.389158010482788, angle of pole: 10.276082038879395 degrees
# Velocity of cart: -1.5854865312576294, angle of pole: 12.813922882080078 degrees
# Velocity of cart: -0.2191038429737091, angle of pole: 0.546908974647522 degrees
# Velocity of cart: -0.4143606424331665, angle of pole: 0.8676269054412842 degrees
# Velocity of cart: -0.6096915602684021, angle of pole: 1.5271670818328857 degrees
# Velocity of cart: -0.8051655888557434, angle of pole: 2.5275192260742188 degrees
# Velocity of cart: -1.0008323192596436, angle of pole: 3.8727262020111084 degrees
# Velocity of cart: -1.1967109441757202, angle of pole: 5.568789005279541 degrees
# Velocity of cart: -1.3927785158157349, angle of pole: 7.6235270500183105 degrees
# Velocity of cart: -1.588955044746399, angle of pole: 10.04638385772705 degrees
# Velocity of cart: -1.7850862741470337, angle of pole: 12.848155975341797 degrees
# Velocity of cart: -0.23987963795661926, angle of pole: -0.32217317819595337 degrees
# Velocity of cart: -0.4349208474159241, angle of pole: -0.036083970218896866 degrees
# Velocity of cart: -0.6300339102745056, angle of pole: 0.5833566784858704 degrees
# Velocity of cart: -0.8252935409545898, angle of pole: 1.5379599332809448 degrees
# Velocity of cart: -1.0207566022872925, angle of pole: 2.831602096557617 degrees
# Velocity of cart: -1.2164525985717773, angle of pole: 4.470141887664795 degrees
# Velocity of cart: -1.412372350692749, angle of pole: 6.4612908363342285 degrees
# Velocity of cart: -1.6084532737731934, angle of pole: 8.814434051513672 degrees
# Velocity of cart: -1.8045638799667358, angle of pole: 11.540387153625488 degrees
# Velocity of cart: -2.0004849433898926, angle of pole: 14.651070594787598 degrees
# Velocity of cart: -0.168790802359581, angle of pole: 1.4063864946365356 degrees
# Velocity of cart: -0.36425310373306274, angle of pole: 1.8064546585083008 degrees
# Velocity of cart: -0.5597997307777405, angle of pole: 2.5506651401519775 degrees
# Velocity of cart: -0.7554916143417358, angle of pole: 3.641448736190796 degrees
# Velocity of cart: -0.951366662979126, angle of pole: 5.083261489868164 degrees
# Velocity of cart: -1.1474286317825317, angle of pole: 6.882475852966309 degrees
# Velocity of cart: -1.3436334133148193, angle of pole: 9.047221183776855 degrees
# Velocity of cart: -1.539873719215393, angle of pole: 11.587160110473633 degrees
# Velocity of cart: -1.7359609603881836, angle of pole: 14.513190269470215 degrees
# Velocity of cart: -0.14581936597824097, angle of pole: -2.3956518173217773 degrees
# Velocity of cart: -0.34032028913497925, angle of pole: -2.0954947471618652 degrees
# Velocity of cart: -0.5349096059799194, angle of pole: -1.4753894805908203 degrees
# Velocity of cart: -0.729669988155365, angle of pole: -0.533352255821228 degrees
# Velocity of cart: -0.9246683120727539, angle of pole: 0.7346678972244263 degrees
# Velocity of cart: -1.1199474334716797, angle of pole: 2.3347151279449463 degrees
# Velocity of cart: -1.315515398979187, angle of pole: 4.274714469909668 degrees
# Velocity of cart: -1.5113334655761719, angle of pole: 6.564315319061279 degrees
# Velocity of cart: -1.7073001861572266, angle of pole: 9.214678764343262 degrees
# Velocity of cart: -1.9032337665557861, angle of pole: 12.238189697265625 degrees
# Velocity of cart: -0.22872856259346008, angle of pole: 1.8038113117218018 degrees
# Velocity of cart: -0.42428553104400635, angle of pole: 2.0974297523498535 degrees
# Velocity of cart: -0.619901716709137, angle of pole: 2.737623929977417 degrees
# Velocity of cart: -0.8156405091285706, angle of pole: 3.7261621952056885 degrees
# Velocity of cart: -1.011545181274414, angle of pole: 5.066857814788818 degrees
# Velocity of cart: -1.207627534866333, angle of pole: 6.765471458435059 degrees
# Velocity of cart: -1.4038550853729248, angle of pole: 8.82956314086914 degrees
# Velocity of cart: -1.6001356840133667, angle of pole: 11.268285751342773 degrees
# Velocity of cart: -1.7963002920150757, angle of pole: 14.09210205078125 degrees
# Velocity of cart: -0.18804587423801422, angle of pole: -0.982535183429718 degrees
# Velocity of cart: -0.38291895389556885, angle of pole: -0.6732796430587769 degrees
# Velocity of cart: -0.5778740048408508, angle of pole: -0.03488824516534805 degrees
# Velocity of cart: -0.3827437460422516, angle of pole: 0.9346242547035217 degrees
# Velocity of cart: -0.1878546178340912, angle of pole: 1.5685275793075562 degrees
# Velocity of cart: 0.006866130977869034, angle of pole: 1.8729808330535889 degrees
# Velocity of cart: 0.2015043944120407, angle of pole: 1.852081298828125 degrees
# Velocity of cart: 0.396151065826416, angle of pole: 1.5078129768371582 degrees
# Velocity of cart: 0.5908946394920349, angle of pole: 0.8400347828865051 degrees
# Velocity of cart: 0.7858140468597412, angle of pole: -0.1535019874572754 degrees
# Velocity of cart: 0.9809707999229431, angle of pole: -1.4771053791046143 degrees
# Velocity of cart: 0.7861751317977905, angle of pole: -3.1370599269866943 degrees
# Velocity of cart: 0.5918070673942566, angle of pole: -4.470981121063232 degrees
# Velocity of cart: 0.39782583713531494, angle of pole: -5.489745140075684 degrees
# Velocity of cart: 0.20416319370269775, angle of pole: -6.202358245849609 degrees
# Velocity of cart: 0.010733114555478096, angle of pole: -6.615846157073975 degrees
# Velocity of cart: -0.1825610101222992, angle of pole: -6.735197067260742 degrees
# Velocity of cart: -0.37582066655158997, angle of pole: -6.563327789306641 degrees
# Velocity of cart: -0.5691474676132202, angle of pole: -6.101073265075684 degrees
# Velocity of cart: -0.7626387476921082, angle of pole: -5.347200870513916 degrees
# Velocity of cart: -0.9563830494880676, angle of pole: -4.298431396484375 degrees
# Velocity of cart: -1.1504546403884888, angle of pole: -2.9494853019714355 degrees
# Velocity of cart: -1.3449068069458008, angle of pole: -1.2931442260742188 degrees
# Velocity of cart: -1.5397632122039795, angle of pole: 0.679657518863678 degrees
# Velocity of cart: -1.7350066900253296, angle of pole: 2.9797041416168213 degrees
# Velocity of cart: -1.930565357208252, angle of pole: 5.619322776794434 degrees
# Velocity of cart: -1.7363256216049194, angle of pole: 8.612139701843262 degrees
# Velocity of cart: -1.5428372621536255, angle of pole: 11.305676460266113 degrees
# Velocity of cart: -1.350164532661438, angle of pole: 13.720829963684082 degrees
# Velocity of cart: 0.2116388976573944, angle of pole: -0.5160166025161743 degrees
# Velocity of cart: 0.40688782930374146, angle of pole: -0.9042078256607056 degrees
# Velocity of cart: 0.6022263169288635, angle of pole: -1.6310279369354248 degrees
# Velocity of cart: 0.7977206110954285, angle of pole: -2.6988847255706787 degrees
# Velocity of cart: 0.9934154748916626, angle of pole: -4.112224578857422 degrees
# Velocity of cart: 1.1893234252929688, angle of pole: -5.877429008483887 degrees
# Velocity of cart: 1.3854122161865234, angle of pole: -8.002667427062988 degrees
# Velocity of cart: 1.5815892219543457, angle of pole: -10.49768352508545 degrees
# Velocity of cart: 1.7776845693588257, angle of pole: -13.373523712158203 degrees
# Velocity of cart: 0.19413143396377563, angle of pole: 2.342717170715332 degrees
# Velocity of cart: 0.3886473476886749, angle of pole: 2.004045248031616 degrees
# Velocity of cart: 0.5832619667053223, angle of pole: 1.3450754880905151 degrees
# Velocity of cart: 0.778056263923645, angle of pole: 0.36357414722442627 degrees
# Velocity of cart: 0.9730947613716125, angle of pole: -0.9447534084320068 degrees
# Velocity of cart: 1.1684162616729736, angle of pole: -2.5861830711364746 degrees
# Velocity of cart: 1.3640236854553223, angle of pole: -4.568854331970215 degrees
# Velocity of cart: 1.5598711967468262, angle of pole: -6.902609825134277 degrees
# Velocity of cart: 1.7558480501174927, angle of pole: -9.598769187927246 degrees
# Velocity of cart: 1.9517608880996704, angle of pole: -12.669835090637207 degrees
# Velocity of cart: 0.18401607871055603, angle of pole: -2.345784902572632 degrees
# Velocity of cart: 0.3796962797641754, angle of pole: -2.7204344272613525 degrees
# Velocity of cart: 0.5754473805427551, angle of pole: -3.4449408054351807 degrees
# Velocity of cart: 0.7713260650634766, angle of pole: -4.521529674530029 degrees
# Velocity of cart: 0.9673656821250916, angle of pole: -5.954444408416748 degrees
# Velocity of cart: 1.1635644435882568, angle of pole: -7.749837398529053 degrees
# Velocity of cart: 1.359871506690979, angle of pole: -9.915599822998047 degrees
# Velocity of cart: 1.556171178817749, angle of pole: -12.461138725280762 degrees
# Velocity of cart: 0.15946894884109497, angle of pole: 2.852109670639038 degrees
# Velocity of cart: -0.03632720559835434, angle of pole: 2.564955234527588 degrees
# Velocity of cart: -0.2320614904165268, angle of pole: 2.6306965351104736 degrees
# Velocity of cart: -0.4278048872947693, angle of pole: 3.0476200580596924 degrees
# Velocity of cart: -0.6236244440078735, angle of pole: 3.8161096572875977 degrees
# Velocity of cart: -0.819572925567627, angle of pole: 4.938624382019043 degrees
# Velocity of cart: -1.0156782865524292, angle of pole: 6.4196248054504395 degrees
# Velocity of cart: -1.2119311094284058, angle of pole: 8.265457153320312 degrees
# Velocity of cart: -1.4082707166671753, angle of pole: 10.484177589416504 degrees
# Velocity of cart: -1.6045684814453125, angle of pole: 13.085306167602539 degrees
# Velocity of cart: -0.23739604651927948, angle of pole: 0.6854918599128723 degrees
# Velocity of cart: -0.4326861798763275, angle of pole: 1.0708667039871216 degrees
# Velocity of cart: -0.6280638575553894, angle of pole: 1.7959271669387817 degrees
# Velocity of cart: -0.8235944509506226, angle of pole: 2.8630547523498535 degrees
# Velocity of cart: -1.0193219184875488, angle of pole: 4.276668071746826 degrees
# Velocity of cart: -1.2152577638626099, angle of pole: 6.04311990737915 degrees
# Velocity of cart: -1.4113681316375732, angle of pole: 8.17054557800293 degrees
# Velocity of cart: -1.6075587272644043, angle of pole: 10.668655395507812 degrees
# Velocity of cart: -1.8036572933197021, angle of pole: 13.548449516296387 degrees
# Velocity of cart: -0.15775944292545319, angle of pole: -0.6249716281890869 degrees
# Velocity of cart: -0.35272446274757385, angle of pole: -0.24130842089653015 degrees
# Velocity of cart: -0.5477873682975769, angle of pole: 0.4737802743911743 degrees
# Velocity of cart: -0.7430201768875122, angle of pole: 1.522735595703125 degrees
# Velocity of cart: -0.9384750127792358, angle of pole: 2.9100453853607178 degrees
# Velocity of cart: -1.1341739892959595, angle of pole: 4.642151832580566 degrees
# Velocity of cart: -1.3300975561141968, angle of pole: 6.727309703826904 degrees
# Velocity of cart: -1.5261694192886353, angle of pole: 9.175396919250488 degrees
# Velocity of cart: -1.7222405672073364, angle of pole: 11.997651100158691 degrees
# Velocity of cart: -1.9180693626403809, angle of pole: 15.206336975097656 degrees
# Velocity of cart: -0.1628929227590561, angle of pole: 0.2893824279308319 degrees
# Velocity of cart: -0.358086496591568, angle of pole: 0.6372033357620239 degrees
# Velocity of cart: -0.553362250328064, angle of pole: 1.3222346305847168 degrees
# Velocity of cart: -0.7487894892692566, angle of pole: 2.3466460704803467 degrees
# Velocity of cart: -0.9444172382354736, angle of pole: 3.7146568298339844 degrees
# Velocity of cart: -1.1402641534805298, angle of pole: 5.432438850402832 degrees
# Velocity of cart: -1.3363062143325806, angle of pole: 7.507977485656738 degrees
# Velocity of cart: -1.5324616432189941, angle of pole: 9.950868606567383 degrees
# Velocity of cart: -1.7285741567611694, angle of pole: 12.772054672241211 degrees
# Velocity of cart: -0.18978330492973328, angle of pole: -0.543441116809845 degrees
# Velocity of cart: -0.3847688138484955, angle of pole: -0.19295033812522888 degrees
# Velocity of cart: -0.1895999014377594, angle of pole: 0.4894854426383972 degrees
# Velocity of cart: 0.00539925554767251, angle of pole: 0.835317850112915 degrees
# Velocity of cart: 0.2003091275691986, angle of pole: 0.848861813545227 degrees
# Velocity of cart: 0.39521661400794983, angle of pole: 0.5323275327682495 degrees
# Velocity of cart: 0.5902069807052612, angle of pole: -0.114200159907341 degrees
# Velocity of cart: 0.7853560447692871, angle of pole: -1.0927470922470093 degrees
# Velocity of cart: 0.9807217717170715, angle of pole: -2.4074013233184814 degrees
# Velocity of cart: 1.1763346195220947, angle of pole: -4.064228534698486 degrees
# Velocity of cart: 1.3721864223480225, angle of pole: -6.071144104003906 degrees
# Velocity of cart: 1.56821608543396, angle of pole: -8.437734603881836 degrees
# Velocity of cart: 1.764293909072876, angle of pole: -11.175017356872559 degrees
# Velocity of cart: 1.9602024555206299, angle of pole: -14.295120239257812 degrees
# Velocity of cart: 0.18671120703220367, angle of pole: 2.5469791889190674 degrees
# Velocity of cart: 0.381172239780426, angle of pole: 2.205416679382324 degrees
# Velocity of cart: 0.5757340788841248, angle of pole: 1.5449022054672241 degrees
# Velocity of cart: 0.7704784870147705, angle of pole: 0.5631725788116455 degrees
# Velocity of cart: 0.965470552444458, angle of pole: -0.7440932989120483 degrees
# Velocity of cart: 1.160750389099121, angle of pole: -2.3831982612609863 degrees
# Velocity of cart: 1.3563224077224731, angle of pole: -4.362311363220215 degrees
# Velocity of cart: 1.55214262008667, angle of pole: -6.6913065910339355 degrees
# Velocity of cart: 1.748103141784668, angle of pole: -9.381542205810547 degrees
# Velocity of cart: 1.9440135955810547, angle of pole: -12.445570945739746 degrees
# Velocity of cart: 0.2125162035226822, angle of pole: -0.5464096069335938 degrees
# Velocity of cart: 0.4077725112438202, angle of pole: -0.9393056631088257 degrees
# Velocity of cart: 0.21288295090198517, angle of pole: -1.6710201501846313 degrees
# Velocity of cart: 0.018187640234827995, angle of pole: -2.0733118057250977 degrees
# Velocity of cart: -0.17639732360839844, angle of pole: -2.150913715362549 degrees
# Velocity of cart: -0.3709630072116852, angle of pole: -1.9064561128616333 degrees
# Velocity of cart: -0.5656002759933472, angle of pole: -1.340444803237915 degrees
# Velocity of cart: -0.7603927850723267, angle of pole: -0.45126956701278687 degrees
# Velocity of cart: -0.9554095268249512, angle of pole: 0.7647565007209778 degrees
# Velocity of cart: -1.1506965160369873, angle of pole: 2.3133277893066406 degrees
# Velocity of cart: -1.3462666273117065, angle of pole: 4.2020392417907715 degrees
# Velocity of cart: -1.5420869588851929, angle of pole: 6.4402360916137695 degrees
# Velocity of cart: -1.7380642890930176, angle of pole: 9.038804054260254 degrees
# Velocity of cart: -1.934027075767517, angle of pole: 12.009894371032715 degrees
# Velocity of cart: -0.19498424232006073, angle of pole: 2.491962432861328 degrees
# Velocity of cart: -0.3906971514225006, angle of pole: 2.883312940597534 degrees
# Velocity of cart: -0.5864827632904053, angle of pole: 3.625399351119995 degrees
# Velocity of cart: -0.7823960781097412, angle of pole: 4.720537185668945 degrees
# Velocity of cart: -0.978468120098114, angle of pole: 6.173054218292236 degrees
# Velocity of cart: -1.1746937036514282, angle of pole: 7.9891767501831055 degrees
# Velocity of cart: -1.3710179328918457, angle of pole: 10.176857948303223 degrees
# Velocity of cart: -1.567319393157959, angle of pole: 12.74554443359375 degrees
# Velocity of cart: -0.17348621785640717, angle of pole: 1.8953863382339478 degrees
# Velocity of cart: -0.36906322836875916, angle of pole: 2.2650463581085205 degrees
# Velocity of cart: -0.5647141337394714, angle of pole: 2.981837272644043 degrees
# Velocity of cart: -0.7604984045028687, angle of pole: 4.047979354858398 degrees
# Velocity of cart: -0.9564530253410339, angle of pole: 5.467720031738281 degrees
# Velocity of cart: -1.1525808572769165, angle of pole: 7.247223377227783 degrees
# Velocity of cart: -1.348836898803711, angle of pole: 9.394413948059082 degrees
# Velocity of cart: -1.54511296749115, angle of pole: 11.918747901916504 degrees
# Velocity of cart: -1.7412195205688477, angle of pole: 14.83092212677002 degrees
# Velocity of cart: -0.23213398456573486, angle of pole: -2.4640371799468994 degrees
# Velocity of cart: -0.03642585128545761, angle of pole: -2.1403138637542725 degrees
# Velocity of cart: 0.15921135246753693, angle of pole: -2.167160987854004 degrees
# Velocity of cart: 0.35485079884529114, angle of pole: -2.542631149291992 degrees
# Velocity of cart: 0.550562858581543, angle of pole: -3.2668800354003906 degrees
# Velocity of cart: 0.746405303478241, angle of pole: -4.3421478271484375 degrees
# Velocity of cart: 0.9424126148223877, angle of pole: -5.772696018218994 degrees
# Velocity of cart: 1.1385846138000488, angle of pole: -7.564695358276367 degrees
# Velocity of cart: 1.3348722457885742, angle of pole: -9.726067543029785 degrees
# Velocity of cart: 1.5311623811721802, angle of pole: -12.26624584197998 degrees
# Velocity of cart: 0.2317076027393341, angle of pole: 0.12049020826816559 degrees
# Velocity of cart: 0.4267995059490204, angle of pole: -0.21038669347763062 degrees
# Velocity of cart: 0.6219727396965027, angle of pole: -0.8758925795555115 degrees
# Velocity of cart: 0.8172991275787354, angle of pole: -1.8781113624572754 degrees
# Velocity of cart: 1.0128315687179565, angle of pole: -3.221182346343994 degrees
# Velocity of cart: 1.2085936069488525, angle of pole: -4.911209583282471 degrees
# Velocity of cart: 1.4045677185058594, angle of pole: -6.956125736236572 degrees
# Velocity of cart: 1.6006810665130615, angle of pole: -9.365503311157227 degrees
# Velocity of cart: 1.7967880964279175, angle of pole: -12.150294303894043 degrees
# Velocity of cart: 0.23675572872161865, angle of pole: -1.7285577058792114 degrees
# Velocity of cart: 0.43229424953460693, angle of pole: -2.0833537578582764 degrees
# Velocity of cart: 0.627905011177063, angle of pole: -2.7842652797698975 degrees
# Velocity of cart: 0.8236492872238159, angle of pole: -3.8334319591522217 degrees
# Velocity of cart: 1.019566297531128, angle of pole: -5.235025882720947 degrees
# Velocity of cart: 1.2156617641448975, angle of pole: -6.995146751403809 degrees
# Velocity of cart: 1.4118951559066772, angle of pole: -9.121665000915527 degrees
# Velocity of cart: 1.6081634759902954, angle of pole: -11.624001502990723 degrees
# Velocity of cart: 1.8042839765548706, angle of pole: -14.51284122467041 degrees
# Velocity of cart: 0.1858544647693634, angle of pole: -0.6402220726013184 degrees
# Velocity of cart: 0.38113412261009216, angle of pole: -0.9410696625709534 degrees
# Velocity of cart: 0.5764827132225037, angle of pole: -1.5813215970993042 degrees
# Velocity of cart: 0.7719696760177612, angle of pole: -2.5628411769866943 degrees
# Velocity of cart: 0.9676451086997986, angle of pole: -3.8895466327667236 degrees
# Velocity of cart: 1.163529872894287, angle of pole: -5.567322254180908 degrees
# Velocity of cart: 1.3596025705337524, angle of pole: -7.603875160217285 degrees
# Velocity of cart: 1.1660411357879639, angle of pole: -10.008548736572266 degrees
# Velocity of cart: 0.9732198715209961, angle of pole: -12.128018379211426 degrees
# Velocity of cart: -0.2310599982738495, angle of pole: 0.14371278882026672 degrees
# Velocity of cart: -0.426217645406723, angle of pole: 0.45751887559890747 degrees
# Velocity of cart: -0.6214507222175598, angle of pole: 1.107620120048523 degrees
# Velocity of cart: -0.8168304562568665, angle of pole: 2.0959818363189697 degrees
# Velocity of cart: -1.0124093294143677, angle of pole: 3.426626205444336 degrees
# Velocity of cart: -1.2082105875015259, angle of pole: 5.1055426597595215 degrees
# Velocity of cart: -1.4042162895202637, angle of pole: 7.140551567077637 degrees
# Velocity of cart: -1.6003532409667969, angle of pole: 9.54111385345459 degrees
# Velocity of cart: -1.7964755296707153, angle of pole: 12.318072319030762 degrees
# Velocity of cart: -0.17859633266925812, angle of pole: -1.176852822303772 degrees
# Velocity of cart: -0.3734191954135895, angle of pole: -0.8716142177581787 degrees
# Velocity of cart: -0.5683242678642273, angle of pole: -0.23848995566368103 degrees
# Velocity of cart: -0.7633891105651855, angle of pole: 0.7244877815246582 degrees
# Velocity of cart: -0.9586743116378784, angle of pole: 2.0213522911071777 degrees
# Velocity of cart: -1.154213786125183, angle of pole: 3.6581199169158936 degrees
# Velocity of cart: -1.3500038385391235, angle of pole: 5.642669200897217 degrees
# Velocity of cart: -1.5459898710250854, angle of pole: 7.984566688537598 degrees
# Velocity of cart: -1.7420496940612793, angle of pole: 10.694832801818848 degrees
# Velocity of cart: -1.9379760026931763, angle of pole: 13.785629272460938 degrees
# Velocity of cart: -0.18996112048625946, angle of pole: 2.4356627464294434 degrees
# Velocity of cart: -0.38566234707832336, angle of pole: 2.7821781635284424 degrees
# Velocity of cart: -0.5814283490180969, angle of pole: 3.479092836380005 degrees
# Velocity of cart: -0.7773165702819824, angle of pole: 4.528460502624512 degrees
# Velocity of cart: -0.9733619093894958, angle of pole: 5.934359073638916 degrees
# Velocity of cart: -1.169564962387085, angle of pole: 7.702782154083252 degrees
# Velocity of cart: -1.3658783435821533, angle of pole: 9.84147834777832 degrees
# Velocity of cart: -1.5621905326843262, angle of pole: 12.359723091125488 degrees
# Velocity of cart: -0.15512464940547943, angle of pole: -2.733506917953491 degrees
# Velocity of cart: -0.3495334982872009, angle of pole: -2.471017360687256 degrees
# Velocity of cart: -0.5440220236778259, angle of pole: -1.8908107280731201 degrees
# Velocity of cart: -0.3484625816345215, angle of pole: -0.9911389946937561 degrees
# Velocity of cart: -0.15310078859329224, angle of pole: -0.43854203820228577 degrees
# Velocity of cart: 0.04212983325123787, angle of pole: -0.22752463817596436 degrees
# Velocity of cart: 0.23730845749378204, angle of pole: -0.3546527028083801 degrees
# Velocity of cart: 0.4325176477432251, angle of pole: -0.8186033368110657 degrees
# Velocity of cart: 0.6278347373008728, angle of pole: -1.6201727390289307 degrees
# Velocity of cart: 0.8233231902122498, angle of pole: -2.762246608734131 degrees
# Velocity of cart: 1.0190229415893555, angle of pole: -4.249731063842773 degrees
# Velocity of cart: 1.2149397134780884, angle of pole: -6.089443683624268 degrees
# Velocity of cart: 1.4110313653945923, angle of pole: -8.28995132446289 degrees
# Velocity of cart: 1.6071927547454834, angle of pole: -10.861352920532227 degrees
# Velocity of cart: 1.4140053987503052, angle of pole: -13.814983367919922 degrees
# Velocity of cart: -0.16421613097190857, angle of pole: 1.7357996702194214 degrees
# Velocity of cart: -0.3597569465637207, angle of pole: 2.0503671169281006 degrees
# Velocity of cart: -0.5553617477416992, angle of pole: 2.7110953330993652 degrees
# Velocity of cart: -0.7510935068130493, angle of pole: 3.719881772994995 degrees
# Velocity of cart: -0.9469943642616272, angle of pole: 5.08066463470459 degrees
# Velocity of cart: -1.1430745124816895, angle of pole: 6.799324989318848 degrees
# Velocity of cart: -1.3392990827560425, angle of pole: 8.883532524108887 degrees
# Velocity of cart: -1.53557288646698, angle of pole: 11.34253978729248 degrees
# Velocity of cart: -1.7317229509353638, angle of pole: 14.186896324157715 degrees
# ...
# Velocity of cart: -0.393025666475296, angle of pole: 1.4836900234222412 degrees
# Velocity of cart: -0.5885041356086731, angle of pole: 1.999776005744934 degrees
# Velocity of cart: -0.7840895652770996, angle of pole: 2.8604750633239746 degrees
# Velocity of cart: -0.5896637439727783, angle of pole: 4.068912029266357 degrees
# Velocity of cart: -0.39558643102645874, angle of pole: 4.960384845733643 degrees
# Velocity of cart: -0.5918146371841431, angle of pole: 5.5430097579956055 degrees
# Velocity of cart: -0.7881169319152832, angle of pole: 6.490792274475098 degrees
# Velocity of cart: -0.9845205545425415, angle of pole: 7.8069586753845215 degrees
# Velocity of cart: -0.7913013696670532, angle of pole: 9.496638298034668 degrees
# Velocity of cart: -0.5986544489860535, angle of pole: 10.903039932250977 degrees
# Velocity of cart: -0.7957429885864258, angle of pole: 12.038429260253906 degrees
# Velocity of cart: -0.23721323907375336, angle of pole: 0.296146422624588 degrees
# Velocity of cart: -0.04216521233320236, angle of pole: 0.6849417686462402 degrees
# Velocity of cart: 0.15278330445289612, angle of pole: 0.7402200698852539 degrees
# Velocity of cart: 0.34771832823753357, angle of pole: 0.46445775032043457 degrees
# Velocity of cart: 0.5427253246307373, angle of pole: -0.14199276268482208 degrees
# Velocity of cart: 0.7378811240196228, angle of pole: -1.080893635749817 degrees
# Velocity of cart: 0.9332456588745117, angle of pole: -2.35607647895813 degrees
# Velocity of cart: 0.7386569380760193, angle of pole: -3.9733617305755615 degrees
# Velocity of cart: 0.5445079803466797, angle of pole: -5.27030611038208 degrees
# Velocity of cart: 0.7407540082931519, angle of pole: -6.2576799392700195 degrees
# Velocity of cart: 0.9371106624603271, angle of pole: -7.6118950843811035 degrees
# Velocity of cart: 1.1335699558258057, angle of pole: -9.338334083557129 degrees
# Velocity of cart: 0.9405815601348877, angle of pole: -11.444111824035645 degrees
# Velocity of cart: 0.7483070492744446, angle of pole: -13.277230262756348 degrees
# Velocity of cart: 0.19029682874679565, angle of pole: -0.36830151081085205 degrees
# Velocity of cart: 0.3855099380016327, angle of pole: -0.6724629998207092 degrees
# Velocity of cart: 0.580794632434845, angle of pole: -1.314329981803894 degrees
# Velocity of cart: 0.3859926462173462, angle of pole: -2.295797109603882 degrees
# Velocity of cart: 0.5816528797149658, angle of pole: -2.950240135192871 degrees
# Velocity of cart: 0.7774355411529541, angle of pole: -3.954224109649658 degrees
# Velocity of cart: 0.973381519317627, angle of pole: -5.311627388000488 degrees
# Velocity of cart: 0.7795003652572632, angle of pole: -7.0282673835754395 degrees
# Velocity of cart: 0.5861495733261108, angle of pole: -8.444269180297852 degrees
# Velocity of cart: 0.7829055786132812, angle of pole: -9.57164478302002 degrees
# Velocity of cart: 0.9796987175941467, angle of pole: -11.083026885986328 degrees
# Velocity of cart: 0.7872864007949829, angle of pole: -12.983980178833008 degrees
# Velocity of cart: -0.2201261967420578, angle of pole: -0.9319758415222168 degrees
# Velocity of cart: -0.02477603778243065, angle of pole: -0.6110809445381165 degrees
# Velocity of cart: 0.17049722373485565, angle of pole: -0.6314034461975098 degrees
# Velocity of cart: 0.3657744228839874, angle of pole: -0.9909500479698181 degrees
# Velocity of cart: 0.1708984524011612, angle of pole: -1.6898456811904907 degrees
# Velocity of cart: -0.023791378363966942, angle of pole: -2.059650421142578 degrees
# Velocity of cart: -0.2183798998594284, angle of pole: -2.104888677597046 degrees
# Velocity of cart: -0.022752953693270683, angle of pole: -1.827978253364563 degrees
# Velocity of cart: 0.17281155288219452, angle of pole: -1.8994728326797485 degrees
# Velocity of cart: 0.3683885931968689, angle of pole: -2.3176937103271484 degrees
# Velocity of cart: 0.17385180294513702, angle of pole: -3.083068609237671 degrees
# Velocity of cart: -0.020466702058911324, angle of pole: -3.5279572010040283 degrees
# Velocity of cart: 0.17548102140426636, angle of pole: -3.657440185546875 degrees
# Velocity of cart: 0.3714464008808136, angle of pole: -4.143825531005859 degrees
# Velocity of cart: 0.5674888491630554, angle of pole: -4.987855911254883 degrees
# Velocity of cart: 0.3736225962638855, angle of pole: -6.19232177734375 degrees
# Velocity of cart: 0.18013811111450195, angle of pole: -7.094109535217285 degrees
# Velocity of cart: -0.013044500723481178, angle of pole: -7.701601505279541 degrees
# Velocity of cart: 0.18371333181858063, angle of pole: -8.021186828613281 degrees
# Velocity of cart: 0.38048577308654785, angle of pole: -8.72107219696045 degrees
# Velocity of cart: 0.1877056509256363, angle of pole: -9.802886009216309 degrees
# Velocity of cart: -0.004684157203882933, angle of pole: -10.608248710632324 degrees
# Velocity of cart: -0.19677415490150452, angle of pole: -11.145106315612793 degrees
# Velocity of cart: 0.0005174672696739435, angle of pole: -11.419449806213379 degrees
# Velocity of cart: 0.19779036939144135, angle of pole: -12.09163761138916 degrees
# Velocity of cart: 0.1527768224477768, angle of pole: 0.23908446729183197 degrees
# Velocity of cart: -0.04240446165204048, angle of pole: -0.052927371114492416 degrees
# Velocity of cart: -0.23751315474510193, angle of pole: -0.008044408634305 degrees
# Velocity of cart: -0.43263310194015503, angle of pole: 0.37189429998397827 degrees
# Velocity of cart: -0.2376023679971695, angle of pole: 1.087172269821167 degrees
# Velocity of cart: -0.04275555536150932, angle of pole: 1.46941077709198 degrees
# Velocity of cart: 0.15198944509029388, angle of pole: 1.5231847763061523 degrees
# Velocity of cart: -0.04350202530622482, angle of pole: 1.250966191291809 degrees
# Velocity of cart: -0.2389301061630249, angle of pole: 1.3236092329025269 degrees
# Velocity of cart: -0.4343726336956024, angle of pole: 1.739443302154541 degrees
# Velocity of cart: -0.23968593776226044, angle of pole: 2.498910903930664 degrees
# Velocity of cart: -0.045209597796201706, angle of pole: 2.934117078781128 degrees
# Velocity of cart: -0.2410266399383545, angle of pole: 3.0500500202178955 degrees
# Velocity of cart: -0.4368613064289093, angle of pole: 3.519371509552002 degrees
# Velocity of cart: -0.6327770352363586, angle of pole: 4.342757225036621 degrees
# Velocity of cart: -0.8288212418556213, angle of pole: 5.522942543029785 degrees
# Velocity of cart: -0.6350345611572266, angle of pole: 7.0646467208862305 degrees
# Velocity of cart: -0.8315483331680298, angle of pole: 8.30722713470459 degrees
# Velocity of cart: -1.0281388759613037, angle of pole: 9.926460266113281 degrees
# Velocity of cart: -1.224755048751831, angle of pole: 11.928738594055176 degrees
# Velocity of cart: -1.4212833642959595, angle of pole: 14.321990966796875 degrees
# Velocity of cart: 0.24072349071502686, angle of pole: -1.3805718421936035 degrees
# Velocity of cart: 0.045953743159770966, angle of pole: -1.6705653667449951 degrees
# Velocity of cart: -0.14873822033405304, angle of pole: -1.6339887380599976 degrees
# Velocity of cart: -0.34344255924224854, angle of pole: -1.2727247476577759 degrees
# Velocity of cart: -0.14801697432994843, angle of pole: -0.586531400680542 degrees
# Velocity of cart: 0.04724938049912453, angle of pole: -0.24365003407001495 degrees
# Velocity of cart: -0.14781132340431213, angle of pole: -0.23983794450759888 degrees
# Velocity of cart: -0.34287333488464355, angle of pole: 0.09782310575246811 degrees
# Velocity of cart: -0.5380191802978516, angle of pole: 0.7693578600883484 degrees
# Velocity of cart: -0.733320951461792, angle of pole: 1.7768982648849487 degrees
# Velocity of cart: -0.538615345954895, angle of pole: 3.124631404876709 degrees
# Velocity of cart: -0.7344328761100769, angle of pole: 4.148297309875488 degrees
# Velocity of cart: -0.9304124116897583, angle of pole: 5.526412010192871 degrees
# Velocity of cart: -1.1265597343444824, angle of pole: 7.26487922668457 degrees
# Velocity of cart: -0.9330463409423828, angle of pole: 9.371376037597656 degrees
# Velocity of cart: -0.7402022480964661, angle of pole: 11.190522193908691 degrees
# Velocity of cart: -0.937166690826416, angle of pole: 12.737475395202637 degrees
# Velocity of cart: -0.1724819540977478, angle of pole: -0.44214871525764465 degrees
# Velocity of cart: 0.0227492768317461, angle of pole: -0.1339317411184311 degrees
# Velocity of cart: -0.17233906686306, angle of pole: -0.1638823002576828 degrees
# Velocity of cart: -0.3674200773239136, angle of pole: 0.14071086049079895 degrees
# Velocity of cart: -0.562576413154602, angle of pole: 0.7796585559844971 degrees
# Velocity of cart: -0.3676426410675049, angle of pole: 1.7548816204071045 degrees
# Velocity of cart: -0.17296355962753296, angle of pole: 2.399653434753418 degrees
# Velocity of cart: 0.02153669483959675, angle of pole: 2.720270872116089 degrees
# Velocity of cart: -0.1742328703403473, angle of pole: 2.72096586227417 degrees
# Velocity of cart: -0.36999818682670593, angle of pole: 3.0737738609313965 degrees
# Velocity of cart: -0.5658270716667175, angle of pole: 3.778691530227661 degrees
# Velocity of cart: -0.3716549873352051, angle of pole: 4.837795257568359 degrees
# Velocity of cart: -0.17780400812625885, angle of pole: 5.586069583892822 degrees
# Velocity of cart: 0.015808623284101486, angle of pole: 6.030738353729248 degrees
# Velocity of cart: -0.18065139651298523, angle of pole: 6.176986217498779 degrees
# Velocity of cart: -0.37711969017982483, angle of pole: 6.694450378417969 degrees
# Velocity of cart: -0.18378190696239471, angle of pole: 7.5839080810546875 degrees
# Velocity of cart: 0.009252967312932014, angle of pole: 8.18258285522461 degrees
# Velocity of cart: 0.20207913219928741, angle of pole: 8.496820449829102 degrees
# Velocity of cart: 0.39479759335517883, angle of pole: 8.530938148498535 degrees
# Velocity of cart: 0.19789531826972961, angle of pole: 8.287211418151855 degrees
# Velocity of cart: 0.0010292321676388383, angle of pole: 8.428168296813965 degrees
# Velocity of cart: -0.19583265483379364, angle of pole: 8.95253849029541 degrees
# Velocity of cart: -0.0031612515449523926, angle of pole: 9.86101245880127 degrees
# Velocity of cart: 0.1891792118549347, angle of pole: 10.494771957397461 degrees
# Velocity of cart: 0.3812843859195709, angle of pole: 10.860502243041992 degrees
# Velocity of cart: 0.18402251601219177, angle of pole: 10.962918281555176 degrees
# Velocity of cart: -0.01321990042924881, angle of pole: 11.461806297302246 degrees
# Velocity of cart: -0.2104465514421463, angle of pole: 12.357611656188965 degrees
# Velocity of cart: 0.1912601888179779, angle of pole: -0.06132354214787483 degrees
# Velocity of cart: 0.3863973915576935, angle of pole: -0.3642532229423523 degrees
# Velocity of cart: 0.58160799741745, angle of pole: -1.0029594898223877 degrees
# Velocity of cart: 0.38672903180122375, angle of pole: -1.9793429374694824 degrees
# Velocity of cart: 0.1921083778142929, angle of pole: -2.6267027854919434 degrees
# Velocity of cart: 0.38785320520401, angle of pole: -2.9513700008392334 degrees
# Velocity of cart: 0.5836571455001831, angle of pole: -3.6275837421417236 degrees
# Velocity of cart: 0.7795774340629578, angle of pole: -4.657259464263916 degrees
# Velocity of cart: 0.585593581199646, angle of pole: -6.044339179992676 degrees
# Velocity of cart: 0.3920387923717499, angle of pole: -7.126440048217773 degrees
# Velocity of cart: 0.1988428235054016, angle of pole: -7.913170337677002 degrees
# Velocity of cart: 0.39562201499938965, angle of pole: -8.412179946899414 degrees
# Velocity of cart: 0.5924270153045654, angle of pole: -9.292590141296387 degrees
# Velocity of cart: 0.3997662663459778, angle of pole: -10.556930541992188 degrees
# Velocity of cart: 0.2075655162334442, angle of pole: -11.548858642578125 degrees
# Velocity of cart: 0.015740202739834785, angle of pole: -12.27773380279541 degrees
# Velocity of cart: -0.15288402140140533, angle of pole: -0.7417747378349304 degrees
# Velocity of cart: 0.04241981357336044, angle of pole: -0.36386606097221375 degrees
# Velocity of cart: -0.15261049568653107, angle of pole: -0.3259931802749634 degrees
# Velocity of cart: -0.3476509749889374, angle of pole: 0.04496576264500618 degrees
# Velocity of cart: -0.5427838563919067, angle of pole: 0.7492523789405823 degrees
# Velocity of cart: -0.34784138202667236, angle of pole: 1.7892119884490967 degrees
# Velocity of cart: -0.1531691998243332, angle of pole: 2.4985241889953613 degrees
# Velocity of cart: 0.041305914521217346, angle of pole: 2.883901596069336 degrees
# Velocity of cart: -0.15450024604797363, angle of pole: 2.9500057697296143 degrees
# Velocity of cart: -0.3503146171569824, angle of pole: 3.369199275970459 degrees
# Velocity of cart: -0.5462023615837097, angle of pole: 4.141865253448486 degrees
# Velocity of cart: -0.3521192967891693, angle of pole: 5.270455360412598 degrees
# Velocity of cart: -0.158382847905159, angle of pole: 6.090645790100098 degrees
# Velocity of cart: -0.35483476519584656, angle of pole: 6.61018180847168 degrees
# Velocity of cart: -0.5513381958007812, angle of pole: 7.501233100891113 degrees
# Velocity of cart: -0.7479159235954285, angle of pole: 8.766585350036621 degrees
# Velocity of cart: -0.5549759864807129, angle of pole: 10.410920143127441 degrees
# Velocity of cart: -0.7519250512123108, angle of pole: 11.778836250305176 degrees
# Velocity of cart: -0.9488418102264404, angle of pole: 13.54058837890625 degrees
# Velocity of cart: -0.2318754494190216, angle of pole: -2.194213390350342 degrees
# Velocity of cart: -0.03622794896364212, angle of pole: -1.9187263250350952 degrees
# Velocity of cart: -0.23085415363311768, angle of pole: -1.9921852350234985 degrees
# Velocity of cart: -0.4254622459411621, angle of pole: -1.7425734996795654 degrees
# Velocity of cart: -0.2299250215291977, angle of pole: -1.1703691482543945 degrees
# Velocity of cart: -0.03451694920659065, angle of pole: -0.944357693195343 degrees
# Velocity of cart: 0.1608372926712036, angle of pole: -1.0610393285751343 degrees
# Velocity of cart: -0.03401713818311691, angle of pole: -1.519016981124878 degrees
# Velocity of cart: -0.2287493646144867, angle of pole: -1.6483607292175293 degrees
# Velocity of cart: -0.03322770819067955, angle of pole: -1.4520328044891357 degrees
# Velocity of cart: 0.1622479408979416, angle of pole: -1.601333737373352 degrees
# Velocity of cart: 0.35775426030158997, angle of pole: -2.0950615406036377 degrees
# Velocity of cart: 0.1631561666727066, angle of pole: -2.9341237545013428 degrees
# Velocity of cart: -0.031205547973513603, angle of pole: -3.4512360095977783 degrees
# Velocity of cart: -0.22541603446006775, angle of pole: -3.6519477367401123 degrees
# Velocity of cart: -0.029441220685839653, angle of pole: -3.5397236347198486 degrees
# Velocity of cart: 0.1665070801973343, angle of pole: -3.7851297855377197 degrees
# Velocity of cart: 0.3624934256076813, angle of pole: -4.3875041007995605 degrees
# Velocity of cart: 0.1684960126876831, angle of pole: -5.348258972167969 degrees
# Velocity of cart: -0.025201493874192238, angle of pole: -6.002308368682861 degrees
# Velocity of cart: 0.17124499380588531, angle of pole: -6.35626745223999 degrees
# Velocity of cart: 0.3677254915237427, angle of pole: -7.081271171569824 degrees
# Velocity of cart: 0.564272940158844, angle of pole: -8.179222106933594 degrees
# Velocity of cart: 0.37122663855552673, angle of pole: -9.65396785736084 degrees
# Velocity of cart: 0.17869412899017334, angle of pole: -10.848197937011719 degrees
# Velocity of cart: -0.013398518785834312, angle of pole: -11.772672653198242 degrees
# Velocity of cart: -0.2051386684179306, angle of pole: -12.436271667480469 degrees
# Velocity of cart: -0.15601259469985962, angle of pole: -0.9045518040657043 degrees
# Velocity of cart: -0.35090550780296326, angle of pole: -0.6307867765426636 degrees
# Velocity of cart: -0.545870840549469, angle of pole: -0.027385758236050606 degrees
# Velocity of cart: -0.7409862279891968, angle of pole: 0.9074066877365112 degrees
# Velocity of cart: -0.9363126754760742, angle of pole: 2.1774165630340576 degrees
# Velocity of cart: -1.1318851709365845, angle of pole: 3.788461685180664 degrees

# %%
import time
import gym
import pygame

# Initialize Gym environment
env = gym.make('CartPole-v0', render_mode="human")

# Initialize Pygame
pygame.init()
screen = pygame.display.set_mode((400, 300))  # Small window just to capture input
pygame.display.set_caption("CartPole Controller")

# Define key-action mapping
action = 0
rewards = 0

# Reset environment
observation, info = env.reset()
env.render()

# Main loop
running = True
while running:
    # Process pygame events (for key input)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_LEFT:
                action = 0  # Move cart left
            elif event.key == pygame.K_RIGHT:
                action = 1  # Move cart right

    # Step through the environment
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated  # Handle both termination cases

    # Print cart velocity and pole angle
    print(f"Cart Velocity: {observation[1]:.1f}, Pole Angle: {observation[2] * 180 / 3.14:.1f}°")

    rewards += 1
    if done:
        print(f"You got {rewards} points!")
        observation, info = env.reset()
        rewards = 0  # Reset reward count

    time.sleep(0.05)  # Reduce speed for better control

env.close()
pygame.quit()
# Out:
# f:\Study_Notes_Backup\Data_Science\DS-GA-3001-Reinforcement\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 35
#      32             action = 1  # Move cart right
#      34 # Step through the environment
# ---> 35 observation, reward, terminated, truncated, info = env.step(action)
#      36 done = terminated or truncated  # Handle both termination cases
#      38 # Print cart velocity and pole angle
#
# File f:\Study_Notes_Backup\Data_Science\DS-GA-3001-Reinforcement\.venv\lib\site-packages\gym\wrappers\time_limit.py:50, in TimeLimit.step(self, action)
#      39 def step(self, action):
#      40     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      41
#      42     Args:
#    (...)
#      48
#      49     """
# ---> 50     observation, reward, terminated, truncated, info = self.env.step(action)
#      51     self._elapsed_steps += 1
#      53     if self._elapsed_steps >= self._max_episode_steps:
#
# File f:\Study_Notes_Backup\Data_Science\DS-GA-3001-Reinforcement\.venv\lib\site-packages\gym\wrappers\order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File f:\Study_Notes_Backup\Data_Science\DS-GA-3001-Reinforcement\.venv\lib\site-packages\gym\wrappers\env_checker.py:37, in PassiveEnvChecker.step(self, action)
#      35 if self.checked_step is False:
#      36     self.checked_step = True
# ---> 37     return env_step_passive_checker(self.env, action)
#      38 else:
#      39     return self.env.step(action)
#
# File f:\Study_Notes_Backup\Data_Science\DS-GA-3001-Reinforcement\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233, in env_step_passive_checker(env, action)
#     230 obs, reward, terminated, truncated, info = result
#     232 # np.bool is actual python bool not np boolean type, therefore bool_ or bool8
# --> 233 if not isinstance(terminated, (bool, np.bool8)):
#     234     logger.warn(
#     235         f"Expects `terminated` signal to be a boolean, actual type: {type(terminated)}"
#     236     )
#     237 if not isinstance(truncated, (bool, np.bool8)):
#
# File f:\Study_Notes_Backup\Data_Science\DS-GA-3001-Reinforcement\.venv\lib\site-packages\numpy\__init__.py:440, in __getattr__(attr)
#     437     import numpy.char as char
#     438     return char.chararray
# --> 440 raise AttributeError("module {!r} has no attribute "
#     441                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'bool8'

# %% [markdown]
# ## **Thank you everyone!**
